# %% [markdown]
# # Dublin House Prices by Post Code
# ## Part 4 - Breaking Down the Data
# We collected and cleaned the Property Price Register house price data in Part 1. In Part 2, we created a Google API object to help us find eirKeys for the addresses, and we then used a Naive Bayes machine learning algorithm to fill as many empty eirKey fields as we could. Now, it's time to examine the data and see what's been going on in the Dublin Housing market so far in 2016.

# %%
import pandas as pd
import bokeh.charts as bc
import bokeh.plotting as bp
import pickle

# %%
with open('pickle/2016/prices_final_dublin_2016_pickle', 'r') as f:
    houses = pickle.load(f)
houses.describe()
# Out:
#                 Lat           Lon         Price
# count  10514.000000  10514.000000  1.127000e+04
# mean      53.352123     -6.263577  4.002353e+05
# std        0.071453      0.089437  7.359560e+05
# min       53.202946     -6.501789  6.500000e+03
# 25%       53.297334     -6.317503  2.200000e+05
# 50%       53.343143     -6.255972  3.030000e+05
# 75%       53.385494     -6.199972  4.500000e+05
# max       53.626983     -6.052932  6.408506e+07

# %% [markdown]
# ### Dublin House Prices

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.boxplot(houses.Price.values, vert=False)
plt.title('Boxplot of 2016 Dublin House Prices')
# Out:
# /Users/anthonymunnelly/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# We can see that there is one price here that is more than a little bigger than the rest.

# %%
houses[houses.Price == houses.Price.max()]
# Out:
#                                      Address       Date  \
# 6544  Westpark, Tallaght, Dublin 24, Ireland 2016-01-15
#
#                         Description FullMarketPrice        Lat       Lon  \
# 6544  New Dwelling house /Apartment              No  53.287019 -6.364894
#
#            Price                                               Size  VAT  \
# 6544  64085057.0  greater than or equal to 38 sq metres and less...  Yes
#
#      eirKey eirKeyName
# 6544    D24   Tallaght

# %%
print "This costs €{:,.2f}.".format(houses[houses.Price == houses.Price.max()]['Price'].loc[6544])
# Out:
# This costs €64,085,057.00.

# %% [markdown]
# Sixty-four million Euro is a considerable chunk of change for "a" house. Again, as we said in Part 1, the sparse descriptions of the properties in the dataset don't always help us understand what's there.
#
# We'll exclude this value from the dataset and carry on.

# %%
houses = houses[houses.Price < houses.Price.max()].copy()
houses.Price.describe()
# Out:
# count    1.126900e+04
# mean     3.945840e+05
# std      4.262765e+05
# min      6.500000e+03
# 25%      2.200000e+05
# 50%      3.030000e+05
# 75%      4.500000e+05
# max      1.815000e+07
# Name: Price, dtype: float64

# %%
plt.boxplot(houses.Price.values, vert=False)
plt.title('Boxplot of 2016 Dublin House Prices')

# %% [markdown]
# ### The Ten Most Expensive Houses

# %%
houses[['Address', 'Date', 'Description', 'Price', 'Size', 'eirKey']].sort_values('Price', ascending = False).head(10)
# Out:
#                                                  Address       Date  \
# 9443         1 Coldcut Cres, Coldcut, Dublin 22, Ireland 2016-08-31
# 10677        KYLEMORE CLINIC, 49 CHURCH ROAD, BALLYBRACK 2016-04-07
# 7250       Johnstown Rd, Cabinteely, Co. Dublin, Ireland 2016-03-10
# 8000                       19 Temple Rd, Dublin, Ireland 2016-05-18
# 10823   APARTMENTS 1-21, BROADSTONE HALL, PHIBSBORO ROAD 2016-06-02
# 1904            5 Temple Pl, Dublin 6, D06 K772, Ireland 2016-04-22
# 9675   Beulah House, Harbour Rd, Glenageary, Dalkey, ... 2016-09-15
# 6080        51 Ailesbury Rd, Dublin 4, D04 YY59, Ireland 2016-10-28
# 8653                   1 Temple Gardens, Dublin, Ireland 2016-07-01
# 8820          Cedar Lodge, Merrion Rd, Dublin 4, Ireland 2016-07-12
#
#                                  Description       Price Size   eirKey
# 9443   Second-Hand Dwelling house /Apartment  18150000.0           D20
# 10677  Second-Hand Dwelling house /Apartment  15450000.0           A96
# 7250   Second-Hand Dwelling house /Apartment  10500000.0           A96
# 8000   Second-Hand Dwelling house /Apartment   8725000.0           D06
# 10823  Second-Hand Dwelling house /Apartment   8500000.0       glugger
# 1904   Second-Hand Dwelling house /Apartment   6500000.0           D06
# 9675   Second-Hand Dwelling house /Apartment   6000000.0           A96
# 6080   Second-Hand Dwelling house /Apartment   5900000.0           D04
# 8653   Second-Hand Dwelling house /Apartment   5850000.0           D06
# 8820   Second-Hand Dwelling house /Apartment   5700000.0           D04

# %% [markdown]
# ### The Ten Least Expensive Houses

# %%
houses[['Address', 'Date', 'Description', 'Price', 'Size', 'eirKey']].sort_values('Price').head(10)
# Out:
#                                                 Address       Date  \
# 5381  2A Ashton Cl, Ballyroan, Dublin 16, D16 C672, ... 2016-09-29
# 5374  2 Ashton Cl, Ballyroan, Dublin 16, D16 T0C6, I... 2016-09-29
# 98             1 Strand Rd, Dublin 4, D04 W9K6, Ireland 2016-01-12
# 1171  13 Castlecurragh Heath, Buzzardstown, Dublin 1... 2016-03-10
# 4187  652 Whitechurch Rd, Rathfarnham, Dublin 16, D1... 2016-08-10
# 897   46 Kenilworth Square S, Dublin 6, D06 Y152, Ir... 2016-02-25
# 610   76 Boot Rd, Brideswell Commons, Dublin 22, D22... 2016-02-11
# 5652  92 Westhaven, Huntstown, Dublin 15, D15 A6KK, ... 2016-10-11
# 5476  7 Clancarthy Rd, Clontarf, Dublin 5, D05 PE03,... 2016-10-03
# 2201  19A Cloonlara Rd, Finglas South, Dublin 11, D1... 2016-05-09
#
#                                 Description    Price Size eirKey
# 5381  Second-Hand Dwelling house /Apartment   6500.0         D16
# 5374  Second-Hand Dwelling house /Apartment   6500.0         D16
# 98    Second-Hand Dwelling house /Apartment   9000.0         D04
# 1171  Second-Hand Dwelling house /Apartment   9031.0         D15
# 4187  Second-Hand Dwelling house /Apartment  10000.0         D16
# 897   Second-Hand Dwelling house /Apartment  10000.0         D06
# 610   Second-Hand Dwelling house /Apartment  10476.0         D22
# 5652  Second-Hand Dwelling house /Apartment  11000.0         D15
# 5476  Second-Hand Dwelling house /Apartment  12000.0         D05
# 2201  Second-Hand Dwelling house /Apartment  12000.0         D11

# %% [markdown]
# ### Houses Sold by eirKeyName
# Let's look at a boxplot of house prices broken down by eirKey. We'll only include those postal areas for which we have one hundred or more data points.

# %%
houses.eirKeyName.value_counts()
# Out:
# Castleknock      956
# Killiney         575
# Stepaside        557
# Tallaght         555
# Blackrock        537
# Crumlin          535
# Ballsbridge      520
# Cabra            519
# Donaghmede       471
# Rathmines        470
# Swords           464
# Malahide         460
# Churchtown       454
# Finglas          441
# Ballinteer       438
# Drumcondra       432
# Lucan            365
# Dolphins Barn    362
# Clontarf         348
# Raheny           308
# Balbriggan       245
# Clondalkin       240
# D02              150
# D01              142
# Skerries         118
# Ballyfermot      118
# Rush              79
# Palmerstown       73
# Lusk              55
# Coolock           55
# Bray              20
# Oldtown Court      3
# Ballyboughal       1
# Dunboyne           1
# Garristown         1
# Name: eirKeyName, dtype: int64

# %%
houses_list = list(houses.eirKey.value_counts().keys())
eirKeyBoxplotData = houses[houses['eirKey'].isin(houses_list[:-10])]
eirKeyBoxplotData.boxplot('Price', 'eirKey', rot=45)

# %% [markdown]
# ### Removing More Outliers
# Again, we see house prices here that are so large they are crushing the distribution visibility of the others. Therefore, we'll cap our house prices at five million Euro or less, and look again.

# %%
bc.output_notebook()
eirKeyBoxplotData = eirKeyBoxplotData[eirKeyBoxplotData.Price < 5000000]
price_v_postcode_boxplot = bc.BoxPlot(eirKeyBoxplotData,
                                      values='Price',
                                      label='eirKeyName',
                                     color = 'skyblue',
                                     whisker_color = 'navy',
                                     marker = 'diamond',
                                     legend = False)

price_v_postcode_boxplot.width = 800
from bokeh.models import NumeralTickFormatter
price_v_postcode_boxplot._yaxis.formatter = NumeralTickFormatter(format = ("€0,000 a"))
price_v_postcode_boxplot.title.text = 'Price v Post Code, 2016-to-Date'
bc.show(price_v_postcode_boxplot)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f037b8a1-6237-4186-b645-0094b68cb951">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="86bcec63-4ed8-43e0-b0c7-b709b4112b78"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#86bcec63-4ed8-43e0-b0c7-b709b4112b78").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("86bcec63-4ed8-43e0-b0c7-b709b4112b78");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '86bcec63-4ed8-43e0-b0c7-b709b4112b78' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"941caf37-9841-44c4-b065-7b890c584832":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"eirKeyName":"Drumcondra"}],"color":["skyblue"],"eirKeyName":["Drumcondra"],"fill_alpha":[0.8],"height":[87907.0],"label":[{"eirKeyName":"Drumcondra"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["Drumcondra"],"y":[378953.5]}},"id":"7e58b9e5-460d-4f6a-a071-e82c095617e5","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"eirKeyName":"D02"}],"color":["skyblue"],"eirKeyName":["D02"],"fill_alpha":[0.8],"height":[62500.0],"label":[{"eirKeyName":"D02"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["D02"],"y":[291250.0]}},"id":"99e2de63-68b8-45de-b6b6-fb847dd78d0e","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"957b6a5f-df0a-4b76-b781-43a35722e38d","type":"ColumnDataSource"},"glyph":{"id":"b5ff6ea4-3b7f-4293-9be8-b354cad1df55","type":"Diamond"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7adeaf7f-3808-4ccc-b65a-b634ada48052","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"5679a8c6-ce2f-4674-84ae-764eea1dad40","type":"ColumnDataSource"},"glyph":{"id":"c4f622b7-ed60-4b82-ba5e-5b81bb9e9129","type":"Diamond"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6c96e809-ca90-49d0-9f45-bad35b904a6f","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2a1f7a66-a04e-4176-a585-bbe2d89038b8","type":"Rect"},{"attributes":{"data_source":{"id":"718c9578-81d4-4e61-8015-219c83ca9997","type":"ColumnDataSource"},"glyph":{"id":"5c4998d6-3d65-47a1-ad0e-a9bb62bebd48","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"fc3bd5dd-dbe1-415a-b419-7109dd0700d2","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"chart_index":[{"eirKeyName":"Clondalkin"},{"eirKeyName":"Clondalkin"},{"eirKeyName":"Clondalkin"},{"eirKeyName":"Clondalkin"}],"eirKeyName":["Clondalkin","Clondalkin","Clondalkin","Clondalkin"],"x0s":["Clondalkin:0.5","Clondalkin:0.65","Clondalkin:0.5","Clondalkin:0.65"],"x1s":["Clondalkin:0.5","Clondalkin:0.35","Clondalkin:0.5","Clondalkin:0.35"],"y0s":[34375.0,34375.0,250000.0,379375.0],"y1s":[163750.0,34375.0,379375.0,379375.0]}},"id":"7508aa93-47f5-4bea-b70e-c5c56c1722fa","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"c4f622b7-ed60-4b82-ba5e-5b81bb9e9129","type":"Diamond"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"eirKeyName":"Balbriggan"}],"color":["skyblue"],"eirKeyName":["Balbriggan"],"fill_alpha":[0.8],"height":[39500.0],"label":[{"eirKeyName":"Balbriggan"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["Balbriggan"],"y":[158250.0]}},"id":"678a09a3-ee11-476e-9667-f905a3d1c74a","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"eirKeyName":"Cabra"},{"eirKeyName":"Cabra"},{"eirKeyName":"Cabra"},{"eirKeyName":"Cabra"},{"eirKeyName":"Cabra"},{"eirKeyName":"Cabra"}],"eirKeyName":["Cabra","Cabra","Cabra","Cabra","Cabra","Cabra"],"x_values":["Cabra:0.5","Cabra:0.5","Cabra:0.5","Cabra:0.5","Cabra:0.5","Cabra:0.5"],"y_values":[775000.0,617000.0,805000.0,750000.0,2562500.0,645120.0]}},"id":"aa932888-aea8-4c ...

# %% [markdown]
# ### Conclusions
# The boxplot is the most eloquent of all the graphs that show data, because it shows the most information in the least amount of space. From one single boxplot we can clearly see:
# 1. Although the most houses sold - for which we have data - are in Dublin 15/Castleknock, these are by no means the most expensive.
# 2. Although the spread of house prices is clearly different for every post code, it is possible to pay well over the odds in any postcode. Every single boxplot above shows outlier data, and that's after capping the value of the houses at five million Euro.
# 3. The least-expensive place to buy a house in 2016 is Dublin 10/Ballyfermot. It's also got the smallest inter-quantile range of all the postal areas. The most expensive house in Dublin 10 just about makes it to the first quartile of house prices in Dublin 4.

# %% [markdown]
# ### When Were the Houses Sold?
# It is remarkable that so many houses are being sold in Dublin 15. If we look at house sales broken down by date and by postal area, can we see if there is any pattern there?

# %%
from bokeh.models import DatetimeTickFormatter, HoverTool

bp.output_notebook()

timeplot = bp.figure(width = 1000, height = 800)

colors = ['red', 'orange', 'purple', 'green', 'blue', 'black', 'coral']

pcs = houses.groupby('eirKeyName')
counter = 0
current_source = {}
renderer = {}
for pc, details in pcs:
    plot_from_zero = pd.DataFrame([0, 0])
    temp = details.copy()
    temp = temp[['Date', 'Address']]
    temp = temp.set_index('Date')
    temp = temp.resample('W').count()
    
    current_source = bp.ColumnDataSource(data = {"pc":[pc],
                                                    "sales":temp.Address.values})
    
    renderer[pc] = timeplot.line(temp.index,
                                 temp.Address.cumsum(),
                                 legend = pc,
                                 color = colors[counter],
                                 alpha = 0.25,
                                 line_width = 2,
                                 hover_alpha = 1,
                                hover_color = colors[counter])
    
    myTooltips = """
                <div>
                    <span style="font-size: 17px; font-weight: bold; color: {}">{}</span>
                </div>
                """
    
    timeplot.add_tools(HoverTool(tooltips = myTooltips.format(colors[counter], pc),
                                renderers = [renderer[pc]],
                                mode = 'mouse'))
    
    
    if counter == 6:
        counter = 0
    else:
        counter += 1
        
timeplot.title.text = "Count of Sales over Time"
timeplot.xaxis.formatter = DatetimeTickFormatter(formats =dict(hours=["%H:%M"],
                                                                days=["%b %d"],
                                                                months=["%b '%y"],
                                                                years=["%b %Y"]))
bp.show(timeplot)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5dd31c24-7183-4494-a170-d5e9e6419e4e">Loading BokehJS ...</span>
#     </div>
# /Users/anthonymunnelly/anaconda/lib/python2.7/site-packages/bokeh/util/deprecation.py:33: BokehDeprecationWarning: DatetimeTickFormatter.formats was deprecated in Bokeh 0.12.3 and will be removed, use individual DatetimeTickFormatter fields instead.
#   warn(message)
#     <div class="bk-root">
#         <div class="plotdiv" id="c2edd659-72ab-408e-aa31-f5b1d370fbe3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c2edd659-72ab-408e-aa31-f5b1d370fbe3").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c2edd659-72ab-408e-aa31-f5b1d370fbe3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c2edd659-72ab-408e-aa31-f5b1d370fbe3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"09f47e98-a0d0-4d94-8780-1b32de24e13a":{"roots":{"references":[{"attributes":{"callback":null,"plot":{"id":"1d1279f7-0ee5-41ae-9a16-613a0a0292b2","subtype":"Figure","type":"Plot"},"renderers":[{"id":"6c54df68-715b-47af-83cf-f5ca4b298777","type":"GlyphRenderer"}],"tooltips":"\n                <div>\n                    <span style=\"font-size: 17px; font-weight: bold; color: black\">Dunboyne</span>\n                </div>\n                "},"id":"6611fc83-067a-46af-8aa9-db66c869348e","type":"HoverTool"},{"attributes":{"label":{"value":"Skerries"},"renderers":[{"id":"973faeb4-b593-4a5b-887c-f28bea26d5f1","type":"GlyphRenderer"}]},"id":"38013e0c-f796-4508-9462-24d2de04842e","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.25},"line_color":{"value":"green"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"9b4f5f15-2f3c-474a-90e3-28b991cf57b9","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"002c8be5-6a7b-4fcc-afea-6cba5b53c43d","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1452384000000.0,1452988800000.0,1453593600000.0,1454198400000.0,1454803200000.0,1455408000000.0,1456012800000.0,1456617600000.0,1457222400000.0,1457827200000.0,1458432000000.0,1459036800000.0,1459641600000.0,1460246400000.0,1460851200000.0,1461456000000.0,1462060800000.0,1462665600000.0,1463270400000.0,1463875200000.0,1464480000000.0,1465084800000.0,1465689600000.0,1466294400000.0,1466899200000.0,1467504000000.0,1468108800000.0,1468713600000.0,1469318400000.0,1469923200000.0,1470528000000.0,1471132800000.0,1471737600000.0,1472342400000.0,1472947200000.0,1473552000000.0,1474156800000.0,1474761600000.0,1475366400000.0,1475971200000.0,1476576000000.0,1477180800000.0,1477785600000.0,1478390400000.0,1478995200000.0,1479600000000.0,1480204800000.0],"y":[9,24,38,56,70,92,113,133,148,175,189,216,235,256,276,289,312,330,350,378,394,426,444,468,491,529,546,562,585,611,623,646,673,693,724,740,761,785,807,834,858,889,914,931,945,953,956]}},"id":"267e55f8-ea9d-4bdb-b313-fdb83df1cb92","type":"ColumnDataSource"},{"attributes":{"callback":null,"plot":{"id":"1d1279f7-0ee5-41ae-9a16-613a0a0292b2","subtype":"Figure","type":"Plot"},"renderers":[{"id":"44b67c29-0698-48ff-bd83-1299fb522666","type":"GlyphRenderer"}],"tooltips":"\n                <div>\n                    <span style=\"font-size: 17px; font-weight: bold; color: blue\">Clontarf</span>\n                </div>\n                "},"id":"ddef72ec-33db-47b1-9827-6971240c7eba","type":"HoverTool"},{"attributes":{"data_source":{"id":"5d2f28e6-45e8-47ee-bd0c-ced2b2f49f75","type":"ColumnDataSource"},"glyph":{"id":"1e43348e-976c-4697-9c5a-4d847ab8b9ce","type":"Line"},"hover_glyph":{"id":"ca5b8a79-db7c-48cb-9388-2ccb2122f41d","type":"Line"},"nonselection_glyph":{"id":"c50c43de-ae4e-46db-a987-ab24e72531d2","type":"Line"},"selection_glyph":null},"id":"c67f7ec9-ee99-4f5b-a55e-82d10d4ecb75","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"4f24dcde-7010-47fc-9dc9-c600a247f829","type":"ColumnDataSource"},"glyph":{"id":"e5738735-c1a2-43c8-a4ba-57e7e153ffc6","type":"Line"},"hover_glyph":{"id":"bce7032e-5fa8-48c8-ab36-bb8c97dceb29","type":"Line"},"nonselection_glyph":{"id":"19fec591-cc72-4ad1-a29c-0e5d4645d287","type":"Line"},"selection_glyph":null},"id":"00a3c8d1-5e50-4bc9-8f0a-fcc641761518","type":"GlyphRenderer"},{"attributes":{"label":{"value":"Lusk"},"renderers":[{"id":"2a9aa50d-953c-4fba-b551-818c83fcbe13","type":"GlyphRenderer"}]},"id":"5f30992e-55eb-4068-a4a5-bde8a54577e7","type":"LegendItem"},{"attributes":{"line_color":{"value":"red"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"3e02095a-4301-4ce2-aafb-d0dc6f1352ab","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"23d3a8b0-0c29-45f4-b5d ...

# %% [markdown]
# ### What's Driving House Sales in Dublin 15?
# Check out our final part, [Part 5](), for maps of Dublin illustrating house prices and rate of houses sold.
