# %% [markdown]
# # DUBLIN HOUSE PRICES
# # 02 - Analysing the Data
# We cleaned the data sourced from the XXX website earlier, and pickled the final data frame. We'll import it now, and examine it to see what we can learn.

# %%
import pandas as pd
import bokeh.charts as bc
import pickle

# %%
with open('Pickles/2016/house_prices_pickle', 'r') as f:
    house_prices = pickle.load(f)
print house_prices.head()
# Out:
#                                              Address  County       Date  \
# 0  34 Mountpleasant Terrace, Dublin 6, D06 YC58, ...  Dublin 2016-01-01
# 3  2 Brighton Rd, Brighton Hall, Kerrymount, Dubl...  Dublin 2016-01-04
# 5  24 Woodstown Meadow, Ballycullen, Dublin 16, D...  Dublin 2016-01-04
# 6  28 Belton Park Gardens, Clontarf, Dublin 9, D0...  Dublin 2016-01-04
# 9  48A Beaufield Park, Stillorgan, Dublin, A94 XH...  Dublin 2016-01-04
#
#                              Description FullMarketPrice        Lat       Lon  \
# 0  Second-Hand Dwelling house /Apartment              No  53.328587 -6.261495
# 3  Second-Hand Dwelling house /Apartment              No  53.258165 -6.174641
# 5  Second-Hand Dwelling house /Apartment              No  53.273761 -6.327188
# 6  Second-Hand Dwelling house /Apartment              No  53.375715 -6.226541
# 9  Second-Hand Dwelling house /Apartment              No  53.290123 -6.203367
#
#   PostCode      Price Size VAT
# 0      D06   170000.0       No
# 3      D18  1150000.0       No
# 5      D16   430000.0       No
# 6      D09   225000.0       No
# 9      A94   345000.0       No

# %%
house_prices.dtypes
# Out:
# Address                    object
# County                     object
# Date               datetime64[ns]
# Description                object
# FullMarketPrice            object
# Lat                       float64
# Lon                       float64
# PostCode                   object
# Price                     float64
# Size                       object
# VAT                        object
# dtype: object

# %%
house_prices['PostCode'].value_counts()
# Out:
# D15    774
# A96    489
# D24    472
# D12    471
# D18    459
# D04    457
# D06    410
# D07    409
# A94    403
# D11    389
# D16    386
# D14    371
# D13    370
# D09    368
# D03    308
# D08    301
# K78    293
# D05    254
# D01    204
# D22    204
# D02    125
# D10    106
# D20     61
# D17     50
# A98     17
# A86      1
# Name: PostCode, dtype: int64

# %% [markdown]
# ### Understanding the Post Codes
# As remarked in the earlier notebook, these post codes are more accurately referred to as Eircode Routing Keys. The Dublin keys are easy to recognise, because they're based on the old post codes - D04 for Dublin 4, D02 for Dublin 2, and so on.
#
# Outside of Dublin, however, there is no way to intuit what each post code / Routing key stands for, and to this end I'm indebted to **Green Party Councillor Ossian Smith of Dun Laoghaire**, who has tabulated [all 139 Eircode Keys on his own site](http://www.ossiansmyth.ie/eircode-routing-keys/). We'll use that table to make our post codes more identifiable.

# %%
from bs4 import BeautifulSoup
import requests
ossian = requests.get('http://www.ossiansmyth.ie/eircode-routing-keys/')
soup = BeautifulSoup(ossian.text, 'lxml')

table_details = []
content = soup.find('div', {'id':'content'})
article = content.find('article', {'id':'post-603'})

table = article.find('table')
print type(table)
# Out:
# <class 'bs4.element.Tag'>

# %%
tr = table.find_all('tr')
table_data = []
for t in tr:
    cells = t.find_all('td')
    temp = []
    [temp.append(c.text) for c in cells]
    table_data.append(temp)
    
print len(table_data)
# Out:
# 142

# %%
post_code_mapper = {}
for t in table_data[3:]:
    post_code_mapper[t[0]] = t[1]
    
house_prices['PostCodeName'] = house_prices['PostCode'].map(post_code_mapper)
postcodenames = house_prices.PostCodeName.value_counts()
house_prices['PostCodeNames'] = house_prices['PostCodeName'].astype('category', categories = postcodenames.keys())

# %%
names = house_prices['PostCodeName'].value_counts()
codes = house_prices['PostCode'].value_counts()
both = zip(names.keys(), codes.keys(), names)
formatter = "{:15}{:5}{:5}"
print formatter.format('POSTCODE NAME', 'CODE', 'COUNT')
for b in both:
    print formatter.format(b[0], b[1], b[2])
# Out:
# POSTCODE NAME  CODE COUNT
# Dublin 15      D15    774
# Dun Laoghaire  A96    489
# Dublin 24      D24    472
# Dublin 12      D12    471
# Dublin 18      D18    459
# Dublin 4       D04    457
# Dublin 6       D06    410
# Dublin 7       D07    409
# Blackrock      A94    403
# Dublin 11      D11    389
# Dublin 16      D16    386
# Dublin 14      D14    371
# Dublin 13      D13    370
# Dublin 9       D09    368
# Dublin 3       D03    308
# Dublin 8       D08    301
# Lucan          K78    293
# Dublin 5       D05    254
# Dublin 22      D01    204
# Dublin 1       D22    204
# Dublin 2       D02    125
# Dublin 10      D10    106
# Dublin 20      D20     61
# Dublin 17      D17     50
# Bray           A98     17
# Dunboyne       A86      1

# %% [markdown]
# ### Breaking Down by Price and Post Code
# Now let's look at the distribution of prices by post code in our data set. For the purposes of clarity, we're going to restrict the data to those post codes for which we have over one hundred properties sold, and we're also going to drop a major development that was in the dataset. It sold for over six million Euro, and such a property is out of place among these others.

# %%
post_codes = house_prices['PostCode'].value_counts()

target = list(post_codes[:-4].keys())
forGraphing = house_prices[house_prices['PostCode'].isin(target)]
forGraphing = forGraphing[forGraphing['Price'] < 1500000]

# %%
bc.output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="56346b2a-5094-47c9-aa35-5802b71f054f">Loading BokehJS ...</span>
#     </div>

# %%
price_v_postcode_boxplot = bc.BoxPlot(forGraphing,
                                      values='Price',
                                      label='PostCode',
                                     color = 'skyblue',
                                     whisker_color = 'navy',
                                     marker = 'diamond')

# %%
price_v_postcode_boxplot.width = 800
from bokeh.models import NumeralTickFormatter
price_v_postcode_boxplot._yaxis.formatter = NumeralTickFormatter(format = ("€0,000 a"))
price_v_postcode_boxplot.title = 'Price v Post Code, 2016-to-Date'
bc.show(price_v_postcode_boxplot)
# Out:
#     <div class="plotdiv" id="13c629e4-ad79-411a-9cac-c61f9df9637f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("13c629e4-ad79-411a-9cac-c61f9df9637f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '13c629e4-ad79-411a-9cac-c61f9df9637f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"986c6c66-afaf-48c2-9807-3dfb90dd84b9":{"roots":{"references":[{"attributes":{"data_source":{"id":"58095193-c4eb-473a-a97d-5f6f99d6f803","type":"ColumnDataSource"},"glyph":{"id":"23d9c585-ff10-47fc-8d21-159a8f6b7332","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"43e9fd1e-ace3-4053-9012-cdbd0cf35cdf","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1454198400000.0,1456704000000.0,1459382400000.0,1461974400000.0,1464652800000.0,1467244800000.0,1469923200000.0,1472601600000.0,1475193600000.0,1477872000000.0],"y":[46,80,108,143,179,226,274,325,369,388]}},"id":"825e956a-408b-4721-ac7b-ccc224827568","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"5f635396-e55e-4523-a5a7-827b4a6dfb09","type":"Line"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"PostCode":["K78"],"chart_index":[{"PostCode":"K78"}],"color":["skyblue"],"fill_alpha":[0.8],"height":[45837.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["K78"],"y":[242081.5]}},"id":"8d3fe6e7-5329-4274-b98d-1b65a64d1668","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1454198400000.0,1456704000000.0,1459382400000.0,1461974400000.0,1464652800000.0,1467244800000.0,1469923200000.0,1472601600000.0,1475193600000.0,1477872000000.0],"y":[22,56,94,125,161,205,259,311,364,389]}},"id":"86ac412b-40ac-4a7d-843a-92c65987ef52","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.25},"line_color":{"value":"red"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"62bef60b-1814-4f59-8295-088e0bfe50c0","type":"Line"},{"attributes":{"data_source":{"id":"c9e1b630-a25c-4eab-a257-c2dd6069a98c","type":"ColumnDataSource"},"glyph":{"id":"c6f396c2-f727-45de-991d-f24d3899e9f5","type":"Line"},"hover_glyph":{"id":"7b6789b2-d0ce-4ff5-8e54-14f72c8d8919","type":"Line"},"nonselection_glyph":{"id":"8cee6f5a-8c81-4f1b-aff7-e42a76853d02","type":"Line"},"selection_glyph":null},"id":"7950a019-8457-429f-9b87-6dd36e33f718","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"PostCode":["D15"],"chart_index":[{"PostCode":"D15"}],"color":["skyblue"],"fill_alpha":[0.8],"height":[62750.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["D15"],"y":[236375.0]}},"id":"df948dd8-d2c4-43da-aac0-c057cd3065f3","type":"ColumnDataSource"},{"attributes":{"callback":null,"plot":{"id":"5d35922b-a8d4-4d2a-8f8d-dd668cac96d1","subtype":"Figure","type":"Plot"},"renderers":[{"id":"75a0d652-5c67-4d21-b46b-eca12663b191","type":"GlyphRenderer"}],"tooltips":[["Post Code","D10"],["Houses Sold","@sales"]]},"id":"11864be6-4ada-45f0-8ead-120d0fed018b","type":"HoverTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"555cf797-4b46-4ce1-bc22-b69ff56c4a4c","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"PostCode":["D14"],"chart_index":[{"PostCode":"D14"}],"color":["skyblue"],"fill_alpha":[0.8],"height":[110000.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["D14"],"y":[540000.0]}},"id":"f9a518d6-5d72-4102-b05b-24b17dce34d2","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"ee4760cb-bab3-4771-8f44-25513e7e439e","type":"Line"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[39]</strong>&gt;</code></p>

# %% [markdown]
# ### Initial Conclusions
# A boxplot is the ideal type of diagram for this data because it can convey so much information in so small a space. The box for each post code show where the middle half of the price values lie. The bottom whisker shows the bottom quarter of prices, the top whisker the most expensive quarter of houses. The red diamond outliers are values that are so high or so low relative to the others that they are mapped separately. So, looking at this data:
# 1. There is a huge range of price difference with postcodes themselves.
# 2. It is possible to buy a very expensive house in half the post codes in the city and environs.
# 3. Dublin 10 has the lowest house prices in the city, followed by Balbriggan (K32).
# 4. The neighbouring post codes of Dublin 6 and Dublin 14 have the most expensive houses in the city. We can go further and say that Dublin 6 has the most uniformly expensive houses in the city - there are no high outliers in the D06 boxplot.

# %% [markdown]
# ### Sales by Time

# %%
import bokeh.plotting as bp
from bokeh.models import DatetimeTickFormatter, HoverTool
bp.output_notebook()
timeplot = bp.figure(width = 1000, height = 800)
colors = ['red', 'orange', 'purple', 'green', 'blue', 'black']

pcs = forGraphing.groupby('PostCodeName')
counter = 0
current_source = {}
renderer = {}
for pc, details in pcs:
    plot_from_zero = pd.DataFrame([0, 0])
    temp = details.copy()
    temp = temp[['Date', 'Address']]
    temp = temp.set_index('Date')
    temp = temp.resample('M').count()
    
    current_source = bp.ColumnDataSource(data = {"pc":pc,
                                                    "sales":temp.Address.values})
    
    renderer[pc] = timeplot.line(temp.index,
                                 temp.Address.cumsum(),
                                 legend = pc,
                                 color = colors[counter],
                                 alpha = 0.25,
                                 line_width = 2,
                                 hover_alpha = 1,
                                hover_color = colors[counter])
    
    myTooltips = """
                <div>
                    <span style="font-size: 17px; font-weight: bold; color: {}">{}</span>
                </div>
                """
    
    timeplot.add_tools(HoverTool(tooltips = myTooltips.format(colors[counter], pc),
                                renderers = [renderer[pc]],
                                mode = 'mouse'))
    
    
    if counter == 5:
        counter = 0
    else:
        counter += 1
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="76e8fd85-f006-41ea-89e3-7a78f42562fc">Loading BokehJS ...</span>
#     </div>

# %%
timeplot.title = "Count of Sales over Time"
timeplot.xaxis.formatter = DatetimeTickFormatter(formats =dict(hours=["%H:%M"],
                                                                days=["%b %d"],
                                                                months=["%b '%y"],
                                                                years=["%b %Y"]))
bp.show(timeplot)
# Out:
#     <div class="plotdiv" id="bd903753-6551-442b-8b58-159021ae28a1"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bd903753-6551-442b-8b58-159021ae28a1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bd903753-6551-442b-8b58-159021ae28a1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"84ae4fcb-9253-47cd-ad4d-8afebceb7349":{"roots":{"references":[{"attributes":{"line_color":{"value":"orange"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"80312ff7-dce5-4f37-9ad0-7c01c474dc71","type":"Line"},{"attributes":{"data_source":{"id":"58095193-c4eb-473a-a97d-5f6f99d6f803","type":"ColumnDataSource"},"glyph":{"id":"23d9c585-ff10-47fc-8d21-159a8f6b7332","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"43e9fd1e-ace3-4053-9012-cdbd0cf35cdf","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1454198400000.0,1456704000000.0,1459382400000.0,1461974400000.0,1464652800000.0,1467244800000.0,1469923200000.0,1472601600000.0,1475193600000.0,1477872000000.0],"y":[46,80,108,143,179,226,274,325,369,388]}},"id":"825e956a-408b-4721-ac7b-ccc224827568","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"5f635396-e55e-4523-a5a7-827b4a6dfb09","type":"Line"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"PostCode":["K78"],"chart_index":[{"PostCode":"K78"}],"color":["skyblue"],"fill_alpha":[0.8],"height":[45837.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["K78"],"y":[242081.5]}},"id":"8d3fe6e7-5329-4274-b98d-1b65a64d1668","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1454198400000.0,1456704000000.0,1459382400000.0,1461974400000.0,1464652800000.0,1467244800000.0,1469923200000.0,1472601600000.0,1475193600000.0,1477872000000.0],"y":[22,56,94,125,161,205,259,311,364,389]}},"id":"86ac412b-40ac-4a7d-843a-92c65987ef52","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.25},"line_color":{"value":"red"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"62bef60b-1814-4f59-8295-088e0bfe50c0","type":"Line"},{"attributes":{"data_source":{"id":"ab61651b-7441-4bd8-8b16-950f56d57570","type":"ColumnDataSource"},"glyph":{"id":"a2f882e5-08df-48f1-a991-b2c2508e68c0","type":"Line"},"hover_glyph":{"id":"a13caee3-42a4-46bd-a3af-618f26e667fc","type":"Line"},"nonselection_glyph":{"id":"ba0814b9-c44d-4f46-8e76-f214ebe85832","type":"Line"},"selection_glyph":null},"id":"148c867a-a03d-4891-bf25-aee7d78ea526","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.25},"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"616c3dae-0cdf-4a52-8b9f-99cd0dead652","type":"Line"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"PostCode":["D15"],"chart_index":[{"PostCode":"D15"}],"color":["skyblue"],"fill_alpha":[0.8],"height":[62750.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["D15"],"y":[236375.0]}},"id":"df948dd8-d2c4-43da-aac0-c057cd3065f3","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"d5057aaa-1d80-4841-ab0b-f1b680281601","type":"LinearAxis"}],"left":[{"id":"01880d67-889f-43ad-8a5b-d46f6162f61b","type":"LinearAxis"}],"plot_height":800,"plot_width":1000,"renderers":[{"id":"d5057aaa-1d80-4841-ab0b-f1b680281601","type":"LinearAxis"},{"id":"935acca0-20d5-4ce0-86ee-f31ef2d7eb1a","type":"Grid"},{"id":"01880d67-889f-43ad-8a5b-d46f6162f61b","type":"LinearAxis"},{"id":"a88d4dae-45db-43f9-af1e-cae9b65e4da7","type":"Grid"},{"id":"9065f426-f104-4f99-94f6-b96e9dcbf970","type":"BoxAnnotation"},{"id":"5a403b3b-659b-4c40-a1dc-ed3e939fe4ef","type":"Legend"},{"id":"eb725107-2b1c-42e6-b102-747235f0b8a9","type":"GlyphRenderer"},{"id":"514e9c0d-6a5c-4256-b408-4cc918546c78","type":"GlyphRenderer"},{"id":"24fe3f75-7cf1-4e71-9f9b-391ea8082121","type":"GlyphRenderer"},{"id":"70f5be59-80d6-466f-b7ca-8f6c7454b8c1","type":"GlyphRenderer"},{"id":"a332dbca-80e3-44c3-853e-4b1eb68003c3","type":"GlyphRenderer"},{"id":"d6b34fb6-5cf5-4e67-ac4d-b09 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[49]</strong>&gt;</code></p>
